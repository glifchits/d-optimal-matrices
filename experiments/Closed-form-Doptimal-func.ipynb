# %% [markdown]
# # Grover's search for D-optimal sequences

# %%
import matplotlib
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
# %config InlineBackend.figure_formats = {'png', 'retina'}
matplotlib.rcParams['figure.figsize'] = (8.0, 5.0)

from quantum import *
from math import log, ceil, floor
from lib import paf, psd


# search for D-optimal sequences length=5
seq_len = 5

# %%
def irange(start, end):
    return range(start, end+1)

def bits_to_seq(bitstring):
    return [-1 if i == '0' else 1 for i in bitstring]

def int_to_seq_pair(bitstring):
    bitmask = (2 ** seq_len) - 1 # 111...1 (length = N)
    # get first half of bitstring
    first_half = (bitstring >> seq_len) & bitmask
    # get second half
    second_half = bitstring & bitmask
    seq_A = bits_to_seq("{:0{width}b}".format(first_half, width=seq_len))
    seq_B = bits_to_seq("{:0{width}b}".format(second_half, width=seq_len))
    return (seq_A, seq_B)

# %%
def bitwise_and(integer):
    """
    Performs AND on each individual bit of the binary representation of `integer`
    """
    if integer == 0: return 0
    result = 1
    for i in range(int(log(integer, 2))):
        bitmask = 0b1 << i
        bit = (integer & bitmask) >> i
        result = result & bit
    return result

# %%
def is_doptimal(integer):
    A, B = int_to_seq_pair(integer)
    m = (seq_len - 1) // 2
    pafs = (paf(A, s) + paf(B, s) for s in irange(1, m))
    # PAF(A,s) + PAF(B,s) = 4k + 2   (for int k, for s = 1..m)
    # PAF(A,s) + PAF(B,s) = 2        (for A,B D-optimal)
    # subtract 2 (so that =0 for D-opt) and square to make non-negative
    S = sum((p - 2)**2 for p in pafs)
    # now we have a positive integer for non-D-optimal pairs
    # NOT then bitwise AND yields 1 if we had 0 (D-opt), otherwise yields 0
    x = np.uint32(S**2)
    return bitwise_and(~x)

def correct_dopt(integer):
    A, B = int_to_seq_pair(integer)
    m = (seq_len - 1) // 2
    pafs = (paf(A, s) + paf(B, s) for s in irange(1, m))
    return all(pafsum == 2 for pafsum in pafs)

from itertools import islice

'''
bad_dopts = (i for i in range(4 ** seq_len) if is_doptimal(i) == 1 and correct_dopt(i) == False)

start = 500
for i in list(islice(bad_dopts, start, start+12)):
    a, b = int_to_seq_pair(i)
    m = (seq_len - 1) // 2
    pafsum = sum(paf(a, s) + paf(b, s) for s in irange(1, m))
    print('a {} \t b {} \t pafsum={}  m={}'.format(a, b, pafsum, m))
'''
#dopt_ints = (i for i in range(4 ** seq_len) if correct_dopt(i))
#for i in list(islice(dopt_ints, 6)) + [1,4,5,124,967335]:
#    a,b = int_to_seq_pair(i)
#    isdopt = is_doptimal(i)
#    print('a', a, 'b', b, 'S', is_doptimal(i))


#dopt = [i for i in range(4 ** seq_len) if is_doptimal(i) == 1]
#print("found {} doptimal pairs length {}".format(len(dopt), seq_len))
# Out:
# "\nbad_dopts = (i for i in range(4 ** seq_len) if is_doptimal(i) == 1 and correct_dopt(i) == False)\n\nstart = 500\nfor i in list(islice(bad_dopts, start, start+12)):\n    a, b = int_to_seq_pair(i)\n    m = (seq_len - 1) // 2\n    pafsum = sum(paf(a, s) + paf(b, s) for s in irange(1, m))\n    print('a {} \t b {} \t pafsum={}  m={}'.format(a, b, pafsum, m))\n"

# %%
num_qubits = 2 * seq_len

# Set up quantum state.
input_register = (zero for _ in range(num_qubits))
state = Q(kron(*input_register, zero))

# Apply HX to the output register.
state = state.apply_gate(X, 0)
state = state.apply_gate(H, 0)

# Apply H^n to the input register.
# input register: qubits 1 to n
input_H = kron(*(H for _ in range(num_qubits)), I)
state = state.apply_unitary(input_H)

N = 2 ** num_qubits
# First, we'll compute the diffusion operator.
# this definition of D (the diffusion matrix aka. inversion about the mean)
# is given in Grover's original paper
P = 1/N * np.ones((N, N))
D = kron(-np.eye(N) + 2*P, I)

#iterations = floor((np.pi/4) * sqrt(N).real)
numsolns = {
    5: 100,
    9: 3888
}
M = numsolns[seq_len]
# optimal num. iterations => see Is-Quantum-Search-Practical (Viamontes)
iterations = floor(1/4 * np.pi * np.arcsin(np.sqrt(M/N))) + 1
print('iterations', iterations)

probs = []

# Perform the Grover iteration,
for i in irange(1, iterations):
    state = state.apply_func(is_doptimal)
    state = state.apply_unitary(D)
    p = [(p**2).real for p in to_row(state.state)]
    probs.append(p)
    
for prob in probs:
    for i, x in enumerate(prob):
        if x > 0.001:
            print("i = {}, is_doptimal = {}, prob = {:.2f}%".format(i, is_doptimal(i), x*100))

for prob_row in probs:
    plt.plot(prob_row)
    plt.show()
# Out:
# iterations 1
# i = 66, is_doptimal = 1, prob = 0.33%
# i = 67, is_doptimal = 0, prob = 0.33%
# i = 68, is_doptimal = 1, prob = 0.33%
# i = 69, is_doptimal = 0, prob = 0.33%
# i = 72, is_doptimal = 1, prob = 0.33%
# i = 73, is_doptimal = 0, prob = 0.33%
# i = 80, is_doptimal = 1, prob = 0.33%
# i = 81, is_doptimal = 0, prob = 0.33%
# i = 94, is_doptimal = 1, prob = 0.33%
# i = 95, is_doptimal = 0, prob = 0.33%
# i = 96, is_doptimal = 0, prob = 0.33%
# i = 97, is_doptimal = 0, prob = 0.33%
# i = 110, is_doptimal = 0, prob = 0.33%
# i = 111, is_doptimal = 0, prob = 0.33%
# i = 118, is_doptimal = 0, prob = 0.33%
# i = 119, is_doptimal = 0, prob = 0.33%
# i = 122, is_doptimal = 0, prob = 0.33%
# i = 123, is_doptimal = 0, prob = 0.33%
# i = 124, is_doptimal = 0, prob = 0.33%
# i = 125, is_doptimal = 0, prob = 0.33%
# i = 130, is_doptimal = 1, prob = 0.33%
# i = 131, is_doptimal = 0, prob = 0.33%
# i = 132, is_doptimal = 1, prob = 0.33%
# i = 133, is_doptimal = 0, prob = 0.33%
# i = 136, is_doptimal = 1, prob = 0.33%
# i = 137, is_doptimal = 0, prob = 0.33%
# i = 144, is_doptimal = 1, prob = 0.33%
# i = 145, is_doptimal = 0, prob = 0.33%
# i = 158, is_doptimal = 1, prob = 0.33%
# i = 159, is_doptimal = 0, prob = 0.33%
# i = 160, is_doptimal = 0, prob = 0.33%
# i = 161, is_doptimal = 0, prob = 0.33%
# i = 174, is_doptimal = 0, prob = 0.33%
# i = 175, is_doptimal = 0, prob = 0.33%
# i = 182, is_doptimal = 0, prob = 0.33%
# i = 183, is_doptimal = 0, prob = 0.33%
# i = 186, is_doptimal = 0, prob = 0.33%
# i = 187, is_doptimal = 0, prob = 0.33%
# i = 188, is_doptimal = 0, prob = 0.33%
# i = 189, is_doptimal = 0, prob = 0.33%
# i = 258, is_doptimal = 1, prob = 0.33%
# i = 259, is_doptimal = 0, prob = 0.33%
# i = 260, is_doptimal = 1, prob = 0.33%
# i = 261, is_doptimal = 0, prob = 0.33%
# i = 264, is_doptimal = 1, prob = 0.33%
# i = 265, is_doptimal = 0, prob = 0.33%
# i = 272, is_doptimal = 1, prob = 0.33%
# i = 273, is_doptimal = 0, prob = 0.33%
# i = 286, is_doptimal = 1, prob = 0.33%
# i = 287, is_doptimal = 0, prob = 0.33%
# i = 288, is_doptimal = 0, prob = 0.33%
# i = 289, is_doptimal = 0, prob = 0.33%
# i = 302, is_doptimal = 0, prob = 0.33%
# i = 303, is_doptimal = 0, prob = 0.33%
# i = 310, is_doptimal = 0, prob = 0.33%
# i = 311, is_doptimal = 0, prob = 0.33%
# i = 314, is_doptimal = 0, prob = 0.33%
# i = 315, is_doptimal = 0, prob = 0.33%
# i = 316, is_doptimal = 0, prob = 0.33%
# i = 317, is_doptimal = 0, prob = 0.33%
# i = 514, is_doptimal = 1, prob = 0.33%
# i = 515, is_doptimal = 0, prob = 0.33%
# i = 516, is_doptimal = 1, prob = 0.33%
# i = 517, is_doptimal = 0, prob = 0.33%
# i = 520, is_doptimal = 1, prob = 0.33%
# i = 521, is_doptimal = 0, prob = 0.33%
# i = 528, is_doptimal = 1, prob = 0.33%
# i = 529, is_doptimal = 0, prob = 0.33%
# i = 542, is_doptimal = 1, prob = 0.33%
# i = 543, is_doptimal = 0, prob = 0.33%
# i = 544, is_doptimal = 0, prob = 0.33%
# i = 545, is_doptimal = 0, prob = 0.33%
# i = 558, is_doptimal = 0, prob = 0.33%
# i = 559, is_doptimal = 0, prob = 0.33%
# i = 566, is_doptimal = 0, prob = 0.33%
# i = 567, is_doptimal = 0, prob = 0.33%
# i = 570, is_doptimal = 0, prob = 0.33%
# i = 571, is_doptimal = 0, prob = 0.33%
# i = 572, is_doptimal = 0, prob = 0.33%
# i = 573, is_doptimal = 0, prob = 0.33%
# i = 962, is_doptimal = 1, prob = 0.33%
# i = 963, is_doptimal = 0, prob = 0.33%
# i = 964, is_doptimal = 1, prob = 0.33%
# i = 965, is_doptimal = 0, prob = 0.33%
# i = 968, is_doptimal = 1, prob = 0.33%
# i = 969, is_doptimal = 0, prob = 0.33%
# i = 976, is_doptimal = 1, prob = 0.33%
# i = 977, is_doptimal = 0, prob = 0.33%
# i = 990, is_doptimal = 1, prob = 0.33%
# i = 991, is_doptimal = 0, prob = 0.33%
# i = 992, is_doptimal = 0, prob = 0.33%
# i = 993, is_doptimal = 0, prob = 0.33%
# i = 1006, is_doptimal = 0, prob = 0.33%
# i = 1007, is_doptimal = 0, prob = 0.33%
# i = 1014, is_doptimal = 0, prob = 0.33%
# i = 1015, is_doptimal = 0, prob = 0.33%
# i = 1018, is_doptimal = 0, prob = 0.33%
# i = 1019, is_doptimal = 0, prob = 0.33%
# i = 1020, is_doptimal = 0, prob = 0.33%
# i = 1021, is_doptimal = 0, prob = 0.33%
# i = 1026, is_doptimal = 0, prob = 0.33%
# i = 1027, is_doptimal = 0, prob = 0.33%
# i = 1028, is_doptimal = 0, prob = 0.33%
# i = 1029, is_doptimal = 0, prob = 0.33%
# i = 1032, is_doptimal = 0, prob = 0.33%
# i = 1033, is_doptimal = 0, prob = 0.33%
# i = 1040, is_doptimal = 0, prob = 0.33%
# i = 1041, is_doptimal = 0, prob = 0.33%
# i = 1054, is_doptimal = 0, prob = 0.33%
# i = 1055, is_doptimal = 0, prob = 0.33%
# i = 1056, is_doptimal = 0, prob = 0.33%
# i = 1057, is_doptimal = 1, prob = 0.33%
# i = 1070, is_doptimal = 0, prob = 0.33%
# i = 1071, is_doptimal = 1, prob = 0.33%
# i = 1078, is_doptimal = 0, prob = 0.33%
# i = 1079, is_doptimal = 1, prob = 0.33%
# i = 1082, is_doptimal = 0, prob = 0.33%
# i = 1083, is_doptimal = 1, prob = 0.33%
# i = 1084, is_doptimal = 0, prob = 0.33%
# i = 1085, is_doptimal = 1, prob = 0.33%
# i = 1474, is_doptimal = 0, prob = 0.33%
# i = 1475, is_doptimal = 0, prob = 0.33%
# i = 1476, is_doptimal = 0, prob = 0.33%
# i = 1477, is_doptimal = 0, prob = 0.33%
# i = 1480, is_doptimal = 0, prob = 0.33%
# i = 1481, is_doptimal = 0, prob = 0.33%
# i = 1488, is_doptimal = 0, prob = 0.33%
# i = 1489, is_doptimal = 0, prob = 0.33%
# i = 1502, is_doptimal = 0, prob = 0.33%
# i = 1503, is_doptimal = 0, prob = 0.33%
# i = 1504, is_doptimal = 0, prob = 0.33%
# i = 1505, is_doptimal = 1, prob = 0.33%
# i = 1518, is_doptimal = 0, prob = 0.33%
# i = 1519, is_doptimal = 1, prob = 0.33%
# i = 1526, is_doptimal = 0, prob = 0.33%
# i = 1527, is_doptimal = 1, prob = 0.33%
# i = 1530, is_doptimal = 0, prob = 0.33%
# i = 1531, is_doptimal = 1, prob = 0.33%
# i = 1532, is_doptimal = 0, prob = 0.33%
# i = 1533, is_doptimal = 1, prob = 0.33%
# i = 1730, is_doptimal = 0, prob = 0.33%
# i = 1731, is_doptimal = 0, prob = 0.33%
# i = 1732, is_doptimal = 0, prob = 0.33%
# i = 1733, is_doptimal = 0, prob = 0.33%
# i = 1736, is_doptimal = 0, prob = 0.33%
# i = 1737, is_doptimal = 0, prob = 0.33%
# i = 1744, is_doptimal = 0, prob = 0.33%
# i = 1745, is_doptimal = 0, prob = 0.33%
# i = 1758, is_doptimal = 0, prob = 0.33%
# i = 1759, is_doptimal = 0, prob = 0.33%
# i = 1760, is_doptimal = 0, prob = 0.33%
# i = 1761, is_doptimal = 1, prob = 0.33%
# i = 1774, is_doptimal = 0, prob = 0.33%
# i = 1775, is_doptimal = 1, prob = 0.33%
# i = 1782, is_doptimal = 0, prob = 0.33%
# i = 1783, is_doptimal = 1, prob = 0.33%
# i = 1786, is_doptimal = 0, prob = 0.33%
# i = 1787, is_doptimal = 1, prob = 0.33%
# i = 1788, is_doptimal = 0, prob = 0.33%
# i = 1789, is_doptimal = 1, prob = 0.33%
# i = 1858, is_doptimal = 0, prob = 0.33%
# i = 1859, is_doptimal = 0, prob = 0.33%
# i = 1860, is_doptimal = 0, prob = 0.33%
# i = 1861, is_doptimal = 0, prob = 0.33%
# i = 1864, is_doptimal = 0, prob = 0.33%
# i = 1865, is_doptimal = 0, prob = 0.33%
# i = 1872, is_doptimal = 0, prob = 0.33%
# i = 1873, is_doptimal = 0, prob = 0.33%
# i = 1886, is_doptimal = 0, prob = 0.33%
# i = 1887, is_doptimal = 0, prob = 0.33%
# i = 1888, is_doptimal = 0, prob = 0.33%
# i = 1889, is_doptimal = 1, prob = 0.33%
# i = 1902, is_doptimal = 0, prob = 0.33%
# i = 1903, is_doptimal = 1, prob = 0.33%
# i = 1910, is_doptimal = 0, prob = 0.33%
# i = 1911, is_doptimal = 1, prob = 0.33%
# i = 1914, is_doptimal = 0, prob = 0.33%
# i = 1915, is_doptimal = 1, prob = 0.33%
# i = 1916, is_doptimal = 0, prob = 0.33%
# i = 1917, is_doptimal = 1, prob = 0.33%
# i = 1922, is_doptimal = 0, prob = 0.33%
# i = 1923, is_doptimal = 0, prob = 0.33%
# i = 1924, is_doptimal = 0, prob = 0.33%
# i = 1925, is_doptimal = 0, prob = 0.33%
# i = 1928, is_doptimal = 0, prob = 0.33%
# i = 1929, is_doptimal = 0, prob = 0.33%
# i = 1936, is_doptimal = 0, prob = 0.33%
# i = 1937, is_doptimal = 0, prob = 0.33%
# i = 1950, is_doptimal = 0, prob = 0.33%
# i = 1951, is_doptimal = 0, prob = 0.33%
# i = 1952, is_doptimal = 0, prob = 0.33%
# i = 1953, is_doptimal = 1, prob = 0.33%
# i = 1966, is_doptimal = 0, prob = 0.33%
# i = 1967, is_doptimal = 1, prob = 0.33%
# i = 1974, is_doptimal = 0, prob = 0.33%
# i = 1975, is_doptimal = 1, prob = 0.33%
# i = 1978, is_doptimal = 0, prob = 0.33%
# i = 1979, is_doptimal = 1, prob = 0.33%
# i = 1980, is_doptimal = 0, prob = 0.33%
# i = 1981, is_doptimal = 1, prob = 0.33%
# <img src="data:image/png;base64,...">
